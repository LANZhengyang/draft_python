# %%
# 1. Write a method leap_year which determines whether a year (as parameter)
# is leap or not (A year A is leap if A is divisible by 4. However, it is 
# not if A is a multiple of 100, unless A is a multiple of 400).

def leap_year(year):
    if (year%4 == 0 and year%100 != 0) or year%400 ==0 :
        return True
    else:
        return False

# assert are here to check your solutions. For the next exercices, you will
# have to write assertions to verify your solutions

assert leap_year(1996) == True
assert leap_year(1998) == False
assert leap_year(1900) == False
assert leap_year(2000) == True

# %%
# adds the multiple numbers of 3 and 5 between these bounds.
# Take for example a = 0, b = 32, the result should then be 0 + 15 + 30 = 45.
def my_bounds(a,b):
    add=0
    if a%15 == 0:
        add=(a//15)*15
    for i in range((b//15)-(a//15)):
        add = add + ((a//15)+i+1)*15
    return add

assert my_bounds(0,32) == 45
assert my_bounds(16,32) == 30
assert my_bounds(31,90) == 45+60+75+90

# %%
def my_bounds2(a,b):
    acc=0
    for i in range(a,b+1):
        if (i%3==0)and (i%5 ==0):
            acc+=i
    return acc

assert my_bounds2(0,32) == 45
assert my_bounds2(16,32) == 30
assert my_bounds2(31,90) == 45+60+75+90

# %%
def my_bounds4(a,b):
    acc=0
    for i in set(range(0,b+1,3)).intersection(set(range(0,b+1,5))).intersection(set(range(a,b+1))):
        acc=acc+1

# %%
return sum([i for i in range()])

# %%
# 3. Slightly modify this program so that it adds the multiple numbers of 3 or 5
# between terminals a and b. With terminals 0 and 32, the result should 
# therefore be: 0 + 3 + 5 + 6 + 9 + 10 + 12 + 15 + 18 + 20 + 21 + 24 + 25 + 27 + 30  = 225.

def my_new_bounds(a,b):
    add_3=0
    if a%3 == 0:
        add_3=(a//3)*3
    for i in range((b//3)-(a//3)):
        add_3 = add_3 + ((a//3)+i+1)*3
        
    add_5=0
    if a%5 == 0:
        add_5=(a//5)*5
    for i in range((b//5)-(a//5)):
        add_5 = add_5 + ((a//5)+i+1)*5
        
    delet_15=0
    if a%15 == 0:
        delet_15=(a//15)*15
    for i in range((b//15)-(a//15)):
        delet_15 = delet_15 + ((a//15)+i+1)*15
        
    return add_3+add_5-delet_15

assert my_new_bounds(0,32) == 225
assert my_new_bounds(0,27) == 195
assert my_new_bounds(5,32) == 222
assert my_new_bounds(10,20) == 10+12+15+18+20

# %%
def my_bounds_new2(a,b):
    return sum(set(range(0,b+1,3))\
               .union(set(range(0,b+1,5)))\
               .intersection(set(range(a,b+1))))

# %%
# 4. Write a function which take a list as parameter and returns a dictionnary
# with each entry contains the entry as key and the number of 
# characters for each entry if the entry is a string (else None)

def check_array_names(*a):
    d = {}
    for i in a:
        if type(i) is str:
            d[i]=len(i)
    return d

# %%
check_array_names("abc",3,"blabla")
# Out:
# {'abc': 3, 'blabla': 6}

# %%
assert check_array_names("abc",3,"blabla") == { "abc": 3, "blabla": 6}
